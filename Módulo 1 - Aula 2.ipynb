# %% [markdown]
# ## Jupyter Notebook
# É um ambiente que viabiliza:
# - Execução de códigos
# - Criação de documento com texto formatado
# - Plotagem de gráficos
#
# > É frequentemente usado para notas de aula

# %%
import ramdom
random.randint?
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import ramdom
#       2 get_ipython().run_line_magic('pinfo', 'random.randint')
#
# ModuleNotFoundError: No module named 'ramdom'

# %%
# fórmulas
num = 3
num = num + 2
num = num * 2
print(num)
# Out:
# 10

# %% [markdown]
# ![0tvdH97V9XRpSGCx6kgDbPbhBsMKXC.jpg](attachment:0tvdH97V9XRpSGCx6kgDbPbhBsMKXC.jpg)
